# %%
# %run utils.ipynb
# %run template_euc.ipynb

first_k = 50; last_k = 80;
exec_times(first_k, last_k)
# Out:
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# The factorization takes too long.
# ...
